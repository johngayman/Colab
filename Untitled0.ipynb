# %% [markdown]
# <a href="https://colab.research.google.com/github/johngayman/Colab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import pandas as pd
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
flic = tfds.load("flic")
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ---------------------------------------------------------------------------
# NonMatchingChecksumError                  Traceback (most recent call last)
# <ipython-input-2-e53b03f6355f> in <module>()
# ----> 1 flic = tfds.load("flic")
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     342   if download:
#     343     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 344     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     345
#     346   if as_dataset_kwargs is None:
#
# ...

# %%
img1 = mpimg.imread("1_predicted.png")
img2 = mpimg.imread("2_predicted.png")
img3 = mpimg.imread("4_predicted.png")
img4 = mpimg.imread("6_predicted.png")

# %%
img = [img1, img2, img3, img4]

# %%
plt.figure(figsize=(20,20))
for i in range(4):
  ax = plt.subplot(2, 2, i+1)
  plt.imshow(img[i])
  plt.axis("off")
  plt.tight_layout()

# %%
img1 = mpimg.imread("7_predicted.png")
img2 = mpimg.imread("8_predicted.png")
img = [img1, img2, img3, img4]
plt.figure(figsize=(20,20))
for i in range(2):
  ax = plt.subplot(1, 2, i+1)
  plt.imshow(img[i])
  plt.axis("off")
  plt.tight_layout()
